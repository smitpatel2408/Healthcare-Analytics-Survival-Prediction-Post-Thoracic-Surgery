# %%
import numpy as np
import pandas as pd
from pandas import DataFrame,Series
import matplotlib.pyplot as plt
import seaborn as sns
from scipy import stats
import scipy.stats as stats

# %%
df = pd.read_csv('Thoracic-Surgery.csv', index_col = 'id')

# %%
df.head()
# Out:
#      DGN  PRE4  PRE5  PRE6 PRE7 PRE8 PRE9 PRE10 PRE11 PRE14 PRE17 PRE19 PRE25  \
# id
# 1   DGN2  2.88  2.16  PRZ1    F    F    F     T     T  OC14     F     F     F
# 2   DGN3  3.40  1.88  PRZ0    F    F    F     F     F  OC12     F     F     F
# 3   DGN3  2.76  2.08  PRZ1    F    F    F     T     F  OC11     F     F     F
# 4   DGN3  3.68  3.04  PRZ0    F    F    F     F     F  OC11     F     F     F
# 5   DGN3  2.44  0.96  PRZ2    F    T    F     T     T  OC11     F     F     F
#
#    PRE30 PRE32  AGE Risk1Yr
# id
# 1      T     F   60       F
# 2      T     F   51       F
# 3      T     F   59       F
# 4      F     F   54       F
# 5      T     F   73       T

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 470 entries, 1 to 470
# Data columns (total 17 columns):
# DGN        470 non-null object
# PRE4       470 non-null float64
# PRE5       470 non-null float64
# PRE6       470 non-null object
# PRE7       470 non-null object
# PRE8       470 non-null object
# PRE9       470 non-null object
# PRE10      470 non-null object
# PRE11      470 non-null object
# PRE14      470 non-null object
# PRE17      470 non-null object
# PRE19      470 non-null object
# PRE25      470 non-null object
# PRE30      470 non-null object
# PRE32      470 non-null object
# AGE        470 non-null int64
# Risk1Yr    470 non-null object
# dtypes: float64(2), int64(1), object(14)
# memory usage: 66.1+ KB

# %%
df[['PRE7', 'PRE8', 'PRE9', 'PRE10', 'PRE11', 'PRE17', 'PRE19', 'PRE25', 'PRE30', 'PRE32', 'Risk1Yr']] = (df[['PRE7', 'PRE8', 'PRE9', 'PRE10', 'PRE11', 'PRE17', 'PRE19', 'PRE25', 'PRE30', 'PRE32', 'Risk1Yr']] == 'T').astype(int)

# %%
df['DGN'] = df['DGN'].str[-1:].astype(int)
df['PRE6'] = df['PRE6'].str[-1:].astype(int)
df['PRE14'] = df['PRE14'].str[-1:].astype(int)

# %%
col = ['Daignosis','Forced_Capacity','Forced_Expiration','Zubrod_scale','Pain','Haemoptysis','Dyspnoea',
       'Cough','Weakness','Size_of_tumor','diabetes','MI_6months','PAD','Smoker','Asthmatic','Age','Risk_1y']
df.columns = col

# %% [markdown]
# # Observation:

# %% [markdown]
# - Pain,Haemoptysis,Dyspnoea,Cough,Weakness,Diabetes Mellitus,Heart Attack in 6 mos,PAD,Smoking,Asthma,DeathIn1yr - Categorical
# - FVC,FEV1,Age - Numerical

# %%
sns.countplot(df['Risk_1y'])
plt.show()

# %%
df['Risk_1y'].value_counts(normalize=True)
# Out:
# 0    0.851064
# 1    0.148936
# Name: Risk_1y, dtype: float64

# %%
df['Smoker'].value_counts(normalize=True)
# Out:
# 1    0.821277
# 0    0.178723
# Name: Smoker, dtype: float64

# %%
df['Cough'].value_counts(normalize=True)
# Out:
# 1    0.687234
# 0    0.312766
# Name: Cough, dtype: float64

# %% [markdown]
# 85% survived 1 year and 15% died within a year.

# %%
fig, axes = plt.subplots(3,1,figsize=(10,15))
sns.countplot(x='Daignosis', hue='Risk_1y', data=df,ax=axes[0]).set_title('Daignosis', fontsize=18)
sns.countplot(x='Size_of_tumor', hue='Risk_1y', data=df, ax=axes[1]).set_title('Size_of_tumor', fontsize=18)
sns.countplot(x='Zubrod_scale', hue='Risk_1y', data=df, ax=axes[2]).set_title('Zubrod_scale', fontsize=18)

plt.tight_layout()

# %%
tab = pd.crosstab(df['diabetes'], df['Risk_1y'])
print(tab)

dummy = tab.div(tab.sum(1).astype(float), axis=0).plot(kind="bar", stacked=True)
plt.title('Diabetes Vs DeathInyr', fontsize=16)
# Out:
# Risk_1y     0   1
# diabetes
# 0         375  60
# 1          25  10
# Text(0.5, 1.0, 'Diabetes Vs DeathInyr')

# %%
tab = pd.crosstab(df['MI_6months'], df['Risk_1y'])
print(tab)

dummy = tab.div(tab.sum(1).astype(float), axis=0).plot(kind="bar", stacked=True)
# Out:
# Risk_1y       0   1
# MI_6months
# 0           398  70
# 1             2   0

# %%
tab = pd.crosstab(df['Asthmatic'], df['Risk_1y'])
print(tab)

dummy = tab.div(tab.sum(1).astype(float), axis=0).plot(kind="bar", stacked=True)
# Out:
# Risk_1y      0   1
# Asthmatic
# 0          398  70
# 1            2   0

# %%
df.head()
# Out:
#     Daignosis  Forced_Capacity  Forced_Expiration  Zubrod_scale  Pain  \
# id
# 1           2             2.88               2.16             1     0
# 2           3             3.40               1.88             0     0
# 3           3             2.76               2.08             1     0
# 4           3             3.68               3.04             0     0
# 5           3             2.44               0.96             2     0
#
#     Haemoptysis  Dyspnoea  Cough  Weakness  Size_of_tumor  diabetes  \
# id
# 1             0         0      1         1              4         0
# 2             0         0      0         0              2         0
# 3             0         0      1         0              1         0
# 4             0         0      0         0              1         0
# 5             1         0      1         1              1         0
#
#     MI_6months  PAD  Smoker  Asthmatic  Age  Risk_1y
# id
# 1            0    0       1          0   60        0
# 2            0    0       1          0   51        0
# 3            0    0       1          0   59        0
# 4            0    0       0          0   54        0
# 5            0    0       1          0   73        1

# %%
#df.drop(['id'], axis = 0) 
corr=df.corr()
corr
# Out:
#                    Daignosis  Forced_Capacity  Forced_Expiration  \
# Daignosis           1.000000         0.121263           0.058780
# Forced_Capacity     0.121263         1.000000           0.032975
# Forced_Expiration   0.058780         0.032975           1.000000
# Zubrod_scale       -0.055900        -0.091094          -0.143155
# Pain                0.047900         0.019786           0.161615
# Haemoptysis        -0.062958        -0.095827           0.102979
# Dyspnoea           -0.047142         0.055829           0.260073
# Cough              -0.075850        -0.052770          -0.099914
# Weakness           -0.019562        -0.100242          -0.086103
# Size_of_tumor      -0.135050         0.034088           0.015504
# diabetes            0.029753        -0.115145          -0.022251
# MI_6months         -0.008675        -0.009135          -0.013617
# PAD                -0.017461        -0.035584          -0.025088
# Smoker             -0.107427        -0.012009          -0.100853
# Asthmatic          -0.008675        -0.060578          -0.016509
# Age                 0.076271        -0.290178          -0.115900
# Risk_1y             0.060444        -0.046374          -0.042841
#
#                    Zubrod_scale      Pain  Haemoptysis  Dyspnoea     Cough  \
# Daignosis             -0.055900  0.047900    -0.062958 -0.047142 -0.075850
# Forced_Capacity       -0.091094  0.019786    -0.095827  0.055829 -0.052770
# Forced_Expiration     -0.143155  0.161615     0.102979  0.260073 -0.099914
# Zubrod_scale           1.000000  0.092863     0.123296  0.092863  0.684647
# %%
mask = np.zeros_like(corr, dtype=np.bool)
mask[np.triu_indices_from(mask)] = True 

sns.heatmap(corr,annot=True, mask=mask, cmap='RdBu_r') 
plt.show()

# %%
# Correlation coefficients for FVC and FEV1
np.corrcoef(df.Forced_Capacity, df.Forced_Expiration)[0,1]
# Out:
# 0.032975265423997376

# %%
# Correlation coefficients for Age and FVC
np.corrcoef(df.Age, df.Forced_Capacity)[0,1]
# Out:
# -0.2901778375988776

# %%
# Correlation coefficients for Age and FEV1
np.corrcoef(df.Age, df.Forced_Expiration)[0,1]
# Out:
# -0.1159000014724894

# %%
sns.pairplot(df)

# %%
tab = pd.crosstab(df['Risk_1y'], df['Dyspnoea'])
print(tab)

dummy = tab.div(tab.sum(1).astype(float), axis=0).plot(kind="bar", stacked=True)
plt.title('DeathInyr vs Dyspnoea', fontsize=16)
# Out:
# Dyspnoea    0   1
# Risk_1y
# 0         378  22
# 1          61   9
# Text(0.5, 1.0, 'DeathInyr vs Dyspnoea')

# %%
tab = pd.crosstab(df['Risk_1y'], df['Pain'])
print(tab)

dummy = tab.div(tab.sum(1).astype(float), axis=0).plot(kind="bar", stacked=True)
plt.title('DeathInyr Vs Pain', fontsize=16)
# Out:
# Pain       0   1
# Risk_1y
# 0        376  24
# 1         63   7
# Text(0.5, 1.0, 'DeathInyr Vs Pain')

# %%
tab = pd.crosstab(df['Risk_1y'], df['Haemoptysis'])
print(tab)

dummy = tab.div(tab.sum(1).astype(float), axis=0).plot(kind="bar", stacked=True)
plt.title('DeathInyr vs Haemopytsis', fontsize=16)
# Out:
# Haemoptysis    0   1
# Risk_1y
# 0            346  54
# 1             56  14
# Text(0.5, 1.0, 'DeathInyr vs Haemopytsis')

# %%
tab = pd.crosstab(df['Risk_1y'], df['Cough'])
print(tab)

dummy = tab.div(tab.sum(1).astype(float), axis=0).plot(kind="bar", stacked=True)
plt.title('DeathIn1yr Vs Cough', fontsize=16)
# Out:
# Cough      0    1
# Risk_1y
# 0        132  268
# 1         15   55
# Text(0.5, 1.0, 'DeathIn1yr Vs Cough')

# %%
tab = pd.crosstab(df['Risk_1y'], df['Smoker'])
print(tab)

dummy = tab.div(tab.sum(1).astype(float), axis=0).plot(kind="bar", stacked=True)
plt.title('DeathIn1yr Vs Smoking', fontsize=16)
# Out:
# Smoker    0    1
# Risk_1y
# 0        77  323
# 1         7   63
# Text(0.5, 1.0, 'DeathIn1yr Vs Smoking')

# %%
fig, (axes1, axes2) = plt.subplots(1,2, figsize = (20 , 6)) 
axes1.scatter(y = df.Risk_1y, x = df.Age)    
axes2.scatter(x = df.Forced_Capacity, y = df.Risk_1y)
plt.title('Forced_Capacity Vs Risk_1y', fontsize=16)
plt.title('Age Vs Risk_1y', fontsize=16)
plt.show()

# %%
plt.scatter(x = df.Forced_Expiration, y = df.Risk_1y) 
plt.show()

# %%
plt.scatter(x = df.Forced_Expiration, y = df.Forced_Capacity) 
plt.show()

# %%
np.corrcoef(df.Forced_Capacity, df.Forced_Expiration)[0,1]
# Out:
# 0.032975265423997376

# %%
sns.swarmplot(y=df.Age,data=df,x=df.Risk_1y)
plt.show()
